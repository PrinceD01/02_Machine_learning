# %%
# Importations
## Import des librairies
import sys
import os
import pandas as pd 
import openpyxl
from datetime import datetime, date, timedelta
from dateutil.relativedelta import relativedelta

## Import du fichier environnement.py
sys.path.append(os.path.abspath("C:/Users/prince.mezuirotimi/OneDrive - Gedeon - SIPAOF/Documents/INTRASIPA/PROJETS/_setup"))
import environnement as env

## Import du fichier d'importation des données
sys.path.append(os.path.abspath("C:/Users/prince.mezuirotimi/OneDrive - Gedeon - SIPAOF/Documents/INTRASIPA/PROJETS/ADDITI - SCORING APPETENCE PRODUIT/01_data_importation"))
from data_importation import cohortes

## Import du fichier de préparation des données à la modélisation
sys.path.append(os.path.abspath("C:/Users/prince.mezuirotimi/OneDrive - Gedeon - SIPAOF/Documents/INTRASIPA/PROJETS/ADDITI - SCORING APPETENCE PRODUIT/02_data_prepare_modelisation"))
from data_prepare_modelisation import apply_prepare_modelisation

## Import du fichier de modélisations
sys.path.append(os.path.abspath("C:/Users/prince.mezuirotimi/OneDrive - Gedeon - SIPAOF/Documents/INTRASIPA/PROJETS/ADDITI - SCORING APPETENCE PRODUIT/03_models"))
from models import run_models




if __name__ == "__main__":
    date_seuil_min = datetime.strptime("2022-01-01", "%Y-%m-%d")
    date_seuil_max = date.today().replace(day=1)
    current_date_heure = datetime.now().strftime('%Y%m%d_%Hh%M')
    
    # Produits ciblés
        # on filtre sur les produits CIBL'AD+ = CIBLAGE + CIBL'AD
        # query qui repertory tous les produits vendus sur la période d'étude avec le nombre de ventes | pour filtrer les produits ciblés
            # pour respecter la casse on ajoute COLLATE Latin1_General_CS_AS avant le like
            
    query = f"""
    WITH PRODUITS_FILTERED AS (
        SELECT 
            CA.Id_offre,
            OFFRE.Libelle,
            COUNT(CA.reference) AS NB,
            CASE 
                WHEN (OFFRE.Libelle COLLATE Latin1_General_CS_AS LIKE '%Manchette%' AND LOWER(OFFRE.Libelle) NOT LIKE '%hors%')
                THEN 1 
                ELSE 0 
            END AS FL_PRODUIT_CIBLE
        FROM FAIT_APUB_PRESTATION_ANALYTIQUE AS CA
        LEFT JOIN (
            SELECT DISTINCT
                Id_offre,
                Libelle
            FROM DIM_OFFRE_PUB
        ) AS OFFRE ON OFFRE.Id_offre = CA.Id_offre
        WHERE CA.Date_facturation >= '{date_seuil_min}' 
            AND CA.Date_facturation <= '{date_seuil_max}'
            AND (CA.Id_etat_prestation IN ('APF', 'VLD') OR (CA.Id_etat_prestation = 'ATT' AND CA.Flag_motif_attente = 2048))
            AND CA.flag_regularisation <> 1 
        GROUP BY CA.Id_offre, OFFRE.Libelle
    )
    
    SELECT * FROM PRODUITS_FILTERED WHERE FL_PRODUIT_CIBLE = 1 AND NB > 0
    """
    produits = tuple(pd.DataFrame(env.sispub(query)).Id_offre)

    
    # Saisons identiques
    start_date = datetime.strptime("2022-11-01", "%Y-%m-%d")
    database = cohortes(start_date=start_date,
                                        produits=produits,
                                        lag_prediction=3, # check lag_prediction=2,4,
                                        step=2)
    

    # Préparation des données pour la modélisation  
    data_train, data_val, data_test, dict_encode_mapping = apply_prepare_modelisation(df=database,
                                                                                        target='FL_ACHAT_PRODUIT',
                                                                                        verbose=True,
                                                                                        id_col='_ID_',
                                                                                        max_modalities=5,
                                                                                        woe_threshold=0.2,
                                                                                        criterion='AIC',
                                                                                        business_cols=['CLASSE_PMG_N', 'PART_DIGITALISATION', 'MOIS_SAISON'],
                                                                                        n_splits=5,
                                                                                        threshold_corr=0.7,
                                                                                        threshold_constant=0.99,
                                                                                        nb_max_features=30,
                                                                                        strate='FL_ACHAT_PRODUIT',
                                                                                        sampling_seuil_min=0.075,
                                                                                        sampling_mode='OVER'
                                                                                )
    
    # Sauvegarde des données
    database.to_csv(f'./00_archives/database{current_date_heure}.csv', sep=';', index=False, header=True, encoding='utf-8-sig')
    data_train.to_csv(f'./00_archives/data_train{current_date_heure}.csv', sep=';', index=True, header=True, encoding='utf-8-sig')
    data_val.to_csv(f'./00_archives/data_val{current_date_heure}.csv', sep=';', index=True, header=True, encoding='utf-8-sig')
    data_test.to_csv(f'./00_archives/data_test{current_date_heure}.csv', sep=';', index=True, header=True, encoding='utf-8-sig')
    

    # Test de modélisation
    models = run_models(data_train=data_train,
                                data_val=data_val,
                                data_test=data_test,
                                dict_encode_mapping=dict_encode_mapping,
                                target='FL_ACHAT_PRODUIT',
                                model_selected='random_forest', # 'all' = 'logistic_regression', 'random_forest', 'xgboost'
                                threshold_decision=0.65,
                                beta=0.5,
                                lift_prct=10
                            )


    # Sauvergarde des modèles
    models_df = pd.DataFrame([
        {
            'model_name': model_info[0],                # model_name
            'model_sklearn': str(model_info[1]), # mdl (modèle sklearn converti en chaîne)
        }
        for model_info in models.values()
    ])
    models_df.to_excel(f'./00_archives/models_details_{current_date_heure}.xlsx', index=False)

    # Sauvegardes des grilles
    for model_info in models.values():
        scores_grid = model_info[2]
        scores_grid.to_csv(f'./00_archives/models_grid_{model_info[0]}_{current_date_heure}.csv', sep=';', index=True, header=True, encoding='utf-8-sig')
# Out:
# ---
#     Lancement de la création des cohortes | Date : 2022-11-01 00:00:00 | Step : 2.
#         ** Cohorte : 1 | Date : 2022-11-01
# ---
#     Lancement du requetage de la base | Date : 2022-11-01.
#     Base requetée avec succès | Nombre de lignes : 47501 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 47501 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 11109 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 2 | Date : 2023-01-01
# ---
#     Lancement du requetage de la base | Date : 2023-01-01.
#     Base requetée avec succès | Nombre de lignes : 48016 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 48016 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 11422 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 3 | Date : 2023-03-01
# ---
#     Lancement du requetage de la base | Date : 2023-03-01.
#     Base requetée avec succès | Nombre de lignes : 48480 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 48480 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 11450 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 4 | Date : 2023-05-01
# ---
#     Lancement du requetage de la base | Date : 2023-05-01.
#     Base requetée avec succès | Nombre de lignes : 48928 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 48928 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 11562 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 5 | Date : 2023-07-01
# ---
#     Lancement du requetage de la base | Date : 2023-07-01.
#     Base requetée avec succès | Nombre de lignes : 49345 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 49345 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 11480 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 6 | Date : 2023-09-01
# ---
#     Lancement du requetage de la base | Date : 2023-09-01.
#     Base requetée avec succès | Nombre de lignes : 49648 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 49648 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 11551 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 7 | Date : 2023-11-01
# ---
#     Lancement du requetage de la base | Date : 2023-11-01.
#     Base requetée avec succès | Nombre de lignes : 50118 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 50118 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 11502 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 8 | Date : 2024-01-01
# ---
#     Lancement du requetage de la base | Date : 2024-01-01.
#     Base requetée avec succès | Nombre de lignes : 50553 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 50553 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 11374 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 9 | Date : 2024-03-01
# ---
#     Lancement du requetage de la base | Date : 2024-03-01.
#     Base requetée avec succès | Nombre de lignes : 50904 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 50904 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 11258 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 10 | Date : 2024-05-01
# ---
#     Lancement du requetage de la base | Date : 2024-05-01.
#     Base requetée avec succès | Nombre de lignes : 51325 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 51325 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 11184 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 11 | Date : 2024-07-01
# ---
#     Lancement du requetage de la base | Date : 2024-07-01.
#     Base requetée avec succès | Nombre de lignes : 51741 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 51741 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 11048 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 12 | Date : 2024-09-01
# ---
#     Lancement du requetage de la base | Date : 2024-09-01.
#     Base requetée avec succès | Nombre de lignes : 52022 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 52022 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 11004 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 13 | Date : 2024-11-01
# ---
#     Lancement du requetage de la base | Date : 2024-11-01.
#     Base requetée avec succès | Nombre de lignes : 52482 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 52482 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 10878 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 14 | Date : 2025-01-01
# ---
#     Lancement du requetage de la base | Date : 2025-01-01.
#     Base requetée avec succès | Nombre de lignes : 56786 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 56786 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 10979 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 15 | Date : 2025-03-01
# ---
#     Lancement du requetage de la base | Date : 2025-03-01.
#     Base requetée avec succès | Nombre de lignes : 57242 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 57242 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 10968 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#         ** Cohorte : 16 | Date : 2025-05-01
# ---
#     Lancement du requetage de la base | Date : 2025-05-01.
#     Base requetée avec succès | Nombre de lignes : 57880 | Nombre de colonnes : 52
# ---
# ---
#     Lancement du prétraitement des données.
#     Prétraitement des données terminé | Nombre de lignes : 57880 | Nombre de colonnes : 60
# ---
# ---
#     Lancement de la création des nouveaux indicateurs.
#     Création des nouveaux indicateurs terminée | Nombre de lignes : 11075 | Nombre de colonnes : 158
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
# ---
#     Lancement du typage des colonnes.
#     Typage des colonnes terminé.
# ---
#     Cohortes créees avec succès | Première date : 2022-11-01 00:00:00 | Dernière date : 2025-05-01 | Nombre de cohortes : 16 | Nombre de lignes : 179844
# ---
#
#
# ---
# 	 Lancement de la préparation des données pour la modélisation
# ---
# 	 Lancement du split des données.
# 	 Split des données terminé :
# 	   > Dataset train | Nombre de lignes :  125890
# 	   > Dataset val   | Nombre de lignes :  26977
# 	   > Dataset test  | Nombre de lignes :  26977
# ---
# ---
# 	 Lancement de la discrétisation des variables.
# 		 Discrétisation de la variable 'NB_CONTACT_AVEC_EMAIL'
# 			 Seuils utilisés : [-inf, np.float64(1.5), np.float64(2.5), np.float64(6.5), inf]
# 			 Entropie pondérée : 0.1386
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT             False  True
# 			   CLASS_NB_CONTACT_AVEC_EMAIL
# 			   bin_-inf_1.5                  99.0    1.0
# 			   bin_1.5_2.5                   98.0    2.0
# 			   bin_2.5_6.5                   97.0    3.0
# 			   bin_6.5_+inf                  96.0    4.0
#
# 		 Discrétisation de la variable 'NB_CONTACT_AVEC_TEL'
# 			 Seuils utilisés : [-inf, np.float64(1.5), np.float64(3.5), np.float64(5.5), inf]
# 			 Entropie pondérée : 0.1389
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT           False  True
# 			   CLASS_NB_CONTACT_AVEC_TEL
# 			   bin_-inf_1.5                99.0    1.0
# 			   bin_1.5_3.5                 98.0    2.0
# 			   bin_3.5_5.5                 97.0    3.0
# 			   bin_5.5_+inf                96.0    4.0
#
# 		 Discrétisation de la variable 'NB_CONTACT_COMPTE'
# 			 Seuils utilisés : [-inf, np.float64(1.5), np.float64(2.5), np.float64(3.5), inf]
# 			 Entropie pondérée : 0.1390
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT         False  True
# 			   CLASS_NB_CONTACT_COMPTE
# 			   bin_-inf_1.5              99.0    1.0
# 			   bin_1.5_2.5               98.0    2.0
# 			   bin_2.5_3.5               98.0    2.0
# 			   bin_3.5_+inf              97.0    3.0
#
# 		 Discrétisation de la variable 'MONTANT_OPPORTUNITE'
# 			 Seuils utilisés : [-inf, np.float64(117.84499740600586), np.float64(381.38999938964844), np.float64(5480.39501953125), inf]
# 			 Entropie pondérée : 0.1362
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT           False  True
# 			   CLASS_MONTANT_OPPORTUNITE
# 			   bin_-inf_117.84            100.0    0.0
# 			   bin_117.84_381.39           97.0    3.0
# 			   bin_381.39_5480.4           98.0    2.0
# 			   bin_5480.4_+inf             96.0    4.0
#
# 		 Discrétisation de la variable 'GAIN_OPPORTUNITE'
# 			 Seuils utilisés : [-inf, np.float64(117.84499740600586), np.float64(295.0299987792969), np.float64(5482.715087890625), inf]
# 			 Entropie pondérée : 0.1377
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT        False  True
# 			   CLASS_GAIN_OPPORTUNITE
# 			   bin_-inf_117.84          99.0    1.0
# 			   bin_117.84_295.03        97.0    3.0
# 			   bin_295.03_5482.72       98.0    2.0
# 			   bin_5482.72_+inf         95.0    5.0
#
# 		 Discrétisation de la variable 'PROBABILITE_OPPORTUNITE'
# 			 Seuils utilisés : [-inf, np.float64(15.0), np.float64(25.0), inf]
# 			 Entropie pondérée : 0.1382
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT               False  True
# 			   CLASS_PROBABILITE_OPPORTUNITE
# 			   bin_-inf_15                     99.0    1.0
# 			   bin_15_25                       96.0    4.0
# 			   bin_25_+inf                     97.0    3.0
#
# 		 Discrétisation de la variable 'NB_CONTACT_DIRECT'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(1.5), np.float64(6.5), inf]
# 			 Entropie pondérée : 0.1366
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT         False  True
# 			   CLASS_NB_CONTACT_DIRECT
# 			   bin_-inf_0.5             100.0    0.0
# 			   bin_0.5_1.5               99.0    1.0
# 			   bin_1.5_6.5               97.0    3.0
# 			   bin_6.5_+inf              96.0    4.0
#
# 		 Discrétisation de la variable 'CA_ANNUEL_ADDITI_N'
# 			 Seuils utilisés : [-inf, np.float64(130.3300018310547), np.float64(345.6750030517578), np.float64(4351.449951171875), inf]
# 			 Entropie pondérée : 0.1308
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT          False  True
# 			   CLASS_CA_ANNUEL_ADDITI_N
# 			   bin_-inf_130.33           100.0    0.0
# 			   bin_130.33_345.68          99.0    1.0
# 			   bin_345.68_4351.45         98.0    2.0
# 			   bin_4351.45_+inf           95.0    5.0
#
# 		 Discrétisation de la variable 'CA_ANNUEL_ADDITI_N1'
# 			 Seuils utilisés : [-inf, np.float64(337.375), np.float64(1532.844970703125), np.float64(5037.44482421875), inf]
# 			 Entropie pondérée : 0.1342
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT           False  True
# 			   CLASS_CA_ANNUEL_ADDITI_N1
# 			   bin_-inf_337.38             99.0    1.0
# 			   bin_337.38_1532.84          98.0    2.0
# 			   bin_1532.84_5037.44         98.0    2.0
# 			   bin_5037.44_+inf            95.0    5.0
#
# 		 Discrétisation de la variable 'CA_DIGITAL_ANNUEL_ADDITI_N'
# 			 Seuils utilisés : [-inf, np.float64(832.885009765625), np.float64(901.7250061035156), np.float64(2752.2850341796875), inf]
# 			 Entropie pondérée : 0.0641
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT                  False  True
# 			   CLASS_CA_DIGITAL_ANNUEL_ADDITI_N
# 			   bin_-inf_832.89                    98.0    2.0
# 			   bin_832.89_901.73                  98.0    2.0
# 			   bin_901.73_2752.29                 96.0    4.0
# 			   bin_2752.29_+inf                   95.0    5.0
#
# 		 Discrétisation de la variable 'PART_DIGITALISATION'
# 			 Seuils utilisés : [-inf, np.float64(0.001468453963752836), np.float64(0.36353059113025665), np.float64(0.9708833694458008), inf]
# 			 Entropie pondérée : 0.1341
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT           False  True
# 			   CLASS_PART_DIGITALISATION
# 			   bin_-inf_0                  99.0    1.0
# 			   bin_0_0.36                  95.0    5.0
# 			   bin_0.36_0.97               96.0    4.0
# 			   bin_0.97_+inf              100.0    0.0
#
# 		 Discrétisation de la variable 'NB_ACHAT'
# 			 Seuils utilisés : [-inf, np.float64(2.5), np.float64(7.5), np.float64(34.5), inf]
# 			 Entropie pondérée : 0.1288
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT  False  True
# 			   CLASS_NB_ACHAT
# 			   bin_-inf_2.5       99.0    1.0
# 			   bin_2.5_7.5        99.0    1.0
# 			   bin_7.5_34.5       97.0    3.0
# 			   bin_34.5_+inf      93.0    7.0
#
# 		 Discrétisation de la variable 'MOY_DELAI_ACHAT'
# 			 Seuils utilisés : [-inf, np.float64(0.9038912951946259), np.float64(6.963834524154663), np.float64(22.568323135375977), inf]
# 			 Entropie pondérée : 0.1308
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT       False  True
# 			   CLASS_MOY_DELAI_ACHAT
# 			   bin_-inf_0.9            99.0    1.0
# 			   bin_0.9_6.96            95.0    5.0
# 			   bin_6.96_22.57          97.0    3.0
# 			   bin_22.57_+inf          98.0    2.0
# 			   Group incalculable     100.0    0.0
#
# 		 Discrétisation de la variable 'VAR_DELAI_ACHAT'
# 			 Seuils utilisés : [-inf, np.float64(14.357142925262451), np.float64(2888.248046875), np.float64(7426.561279296875), inf]
# 			 Entropie pondérée : 0.1310
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT       False  True
# 			   CLASS_VAR_DELAI_ACHAT
# 			   bin_-inf_14.36          99.0    1.0
# 			   bin_14.36_2888.25       96.0    4.0
# 			   bin_2888.25_7426.56     97.0    3.0
# 			   bin_7426.56_+inf        99.0    1.0
# 			   Group incalculable     100.0    0.0
#
# 		 Discrétisation de la variable 'RECENCE'
# 			 Seuils utilisés : [-inf, np.float64(32.5), np.float64(373.5), np.float64(422.5), inf]
# 			 Entropie pondérée : 0.1329
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT    False  True
# 			   CLASS_RECENCE
# 			   bin_-inf_32.5        96.0    4.0
# 			   bin_32.5_373.5       97.0    3.0
# 			   bin_373.5_422.5      99.0    1.0
# 			   bin_422.5_+inf       99.0    1.0
# 			   Group incalculable  100.0    0.0
#
# 		 Discrétisation de la variable 'SQRT_DELAI_ACHAT'
# 			 Seuils utilisés : [-inf, np.float64(3.7890819311141968), np.float64(53.74242401123047), np.float64(86.1775016784668), inf]
# 			 Entropie pondérée : 0.1310
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT        False  True
# 			   CLASS_SQRT_DELAI_ACHAT
# 			   bin_-inf_3.79            99.0    1.0
# 			   bin_3.79_53.74           96.0    4.0
# 			   bin_53.74_86.18          97.0    3.0
# 			   bin_86.18_+inf           99.0    1.0
# 			   Group incalculable      100.0    0.0
#
# 		 Discrétisation de la variable 'NB_GP_PUB_CO'
# 			 Seuils utilisés : [-inf, np.float64(1.5), np.float64(5.5), np.float64(37.5), inf]
# 			 Entropie pondérée : 0.1270
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT    False  True
# 			   CLASS_NB_GP_PUB_CO
# 			   bin_-inf_1.5        100.0    0.0
# 			   bin_1.5_5.5          99.0    1.0
# 			   bin_5.5_37.5         97.0    3.0
# 			   bin_37.5_+inf        94.0    6.0
#
# 		 Discrétisation de la variable 'RF_GP_PUB_CO'
# 			 Seuils utilisés : [-inf, np.float64(-0.4519519507884979), np.float64(9.835585594177246), np.float64(19.219219207763672), inf]
# 			 Entropie pondérée : 0.1319
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT    False  True
# 			   CLASS_RF_GP_PUB_CO
# 			   bin_-inf_-0.45      100.0    0.0
# 			   bin_-0.45_9.84       97.0    3.0
# 			   bin_9.84_19.22       98.0    2.0
# 			   bin_19.22_+inf       94.0    6.0
#
# 		 Discrétisation de la variable 'NB_GP_DISPLAY'
# 			 Seuils utilisés : [-inf, np.float64(1.5), np.float64(4.5), np.float64(10.5), inf]
# 			 Entropie pondérée : 0.1356
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT     False  True
# 			   CLASS_NB_GP_DISPLAY
# 			   bin_-inf_1.5          99.0    1.0
# 			   bin_1.5_4.5           98.0    2.0
# 			   bin_4.5_10.5          97.0    3.0
# 			   bin_10.5_+inf         95.0    5.0
#
# 		 Discrétisation de la variable 'RF_GP_DISPLAY'
# 			 Seuils utilisés : [-inf, np.float64(-0.4797297269105911), np.float64(1.708494246006012), np.float64(19.24662208557129), inf]
# 			 Entropie pondérée : 0.1350
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT     False  True
# 			   CLASS_RF_GP_DISPLAY
# 			   bin_-inf_-0.48        97.0    3.0
# 			   bin_-0.48_1.71        99.0    1.0
# 			   bin_1.71_19.25        97.0    3.0
# 			   bin_19.25_+inf        93.0    7.0
#
# 		 Discrétisation de la variable 'NB_GP_SOCIAL'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(3.5), np.float64(6.5), inf]
# 			 Entropie pondérée : 0.1392
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT    False  True
# 			   CLASS_NB_GP_SOCIAL
# 			   bin_-inf_0.5         98.0    2.0
# 			   bin_0.5_3.5          95.0    5.0
# 			   bin_3.5_6.5          97.0    3.0
# 			   bin_6.5_+inf         96.0    4.0
#
# 		 Discrétisation de la variable 'RF_GP_SOCIAL'
# 			 Seuils utilisés : [-inf, np.float64(-0.7361111044883728), np.float64(-0.563492089509964), np.float64(0.08220720663666725), inf]
# 			 Entropie pondérée : 0.1337
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT    False  True
# 			   CLASS_RF_GP_SOCIAL
# 			   bin_-inf_-0.74       95.0    5.0
# 			   bin_-0.74_-0.56      97.0    3.0
# 			   bin_-0.56_0.08       99.0    1.0
# 			   bin_0.08_+inf        96.0    4.0
#
# 		 Discrétisation de la variable 'NB_GP_AUTRE'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(1.5), np.float64(3.5), inf]
# 			 Entropie pondérée : 0.1363
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT   False  True
# 			   CLASS_NB_GP_AUTRE
# 			   bin_-inf_0.5        99.0    1.0
# 			   bin_0.5_1.5         98.0    2.0
# 			   bin_1.5_3.5         97.0    3.0
# 			   bin_3.5_+inf        95.0    5.0
#
# 		 Discrétisation de la variable 'RF_GP_AUTRE'
# 			 Seuils utilisés : [-inf, np.float64(-0.4797297269105911), np.float64(0.60285285115242), np.float64(18.657657623291016), inf]
# 			 Entropie pondérée : 0.1347
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT   False  True
# 			   CLASS_RF_GP_AUTRE
# 			   bin_-inf_-0.48      97.0    3.0
# 			   bin_-0.48_0.6       99.0    1.0
# 			   bin_0.6_18.66       97.0    3.0
# 			   bin_18.66_+inf      94.0    6.0
#
# 		 Discrétisation de la variable 'NB_GP_DIVERTO'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(3.5), np.float64(14.5), inf]
# 			 Entropie pondérée : 0.1383
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT     False  True
# 			   CLASS_NB_GP_DIVERTO
# 			   bin_-inf_0.5          98.0    2.0
# 			   bin_0.5_3.5           98.0    2.0
# 			   bin_3.5_14.5          96.0    4.0
# 			   bin_14.5_+inf         93.0    7.0
#
# 		 Discrétisation de la variable 'RF_GP_DIVERTO'
# 			 Seuils utilisés : [-inf, np.float64(-0.7361111044883728), np.float64(-0.4797297269105911), np.float64(-0.39714714884757996), inf]
# 			 Entropie pondérée : 0.1348
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT     False  True
# 			   CLASS_RF_GP_DIVERTO
# 			   bin_-inf_-0.74        96.0    4.0
# 			   bin_-0.74_-0.48       97.0    3.0
# 			   bin_-0.48_-0.4        99.0    1.0
# 			   bin_-0.4_+inf         96.0    4.0
#
# 		 Discrétisation de la variable 'NB_GP_PROG_BU'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(2.5), np.float64(4.5), inf]
# 			 Entropie pondérée : 0.1395
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT     False  True
# 			   CLASS_NB_GP_PROG_BU
# 			   bin_-inf_0.5          98.0    2.0
# 			   bin_0.5_2.5           97.0    3.0
# 			   bin_2.5_4.5           95.0    5.0
# 			   bin_4.5_+inf          97.0    3.0
#
# 		 Discrétisation de la variable 'RF_GP_PROG_BU'
# 			 Seuils utilisés : [-inf, np.float64(-0.7361111044883728), np.float64(-0.7182539701461792), np.float64(-0.43050193786621094), inf]
# 			 Entropie pondérée : 0.1340
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT     False  True
# 			   CLASS_RF_GP_PROG_BU
# 			   bin_-inf_-0.74        95.0    5.0
# 			   bin_-0.74_-0.72       97.0    3.0
# 			   bin_-0.72_-0.43       99.0    1.0
# 			   bin_-0.43_+inf        97.0    3.0
#
# 		 Discrétisation de la variable 'NB_GP_REF_PAYANT'
# 			 Seuils utilisés : [-inf, np.float64(0.5), inf]
# 			 Entropie pondérée : 0.1399
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT        False  True
# 			   CLASS_NB_GP_REF_PAYANT
# 			   bin_-inf_0.5             98.0    2.0
# 			   bin_0.5_+inf             96.0    4.0
#
# 		 Discrétisation de la variable 'RF_GP_REF_PAYANT'
# 			 Seuils utilisés : [-inf, np.float64(-0.7361111044883728), np.float64(-0.4797297269105911), np.float64(1.7672672867774963), inf]
# 			 Entropie pondérée : 0.1333
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT        False  True
# 			   CLASS_RF_GP_REF_PAYANT
# 			   bin_-inf_-0.74           95.0    5.0
# 			   bin_-0.74_-0.48          97.0    3.0
# 			   bin_-0.48_1.77           99.0    1.0
# 			   bin_1.77_+inf            95.0    5.0
#
# 		 Discrétisation de la variable 'NB_GP_SUPPLEMENT_PUB_CO'
# 			 Seuils utilisés : [-inf, np.float64(1.5), np.float64(3.5), np.float64(7.5), inf]
# 			 Entropie pondérée : 0.1388
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT               False  True
# 			   CLASS_NB_GP_SUPPLEMENT_PUB_CO
# 			   bin_-inf_1.5                    98.0    2.0
# 			   bin_1.5_3.5                     99.0    1.0
# 			   bin_3.5_7.5                     98.0    2.0
# 			   bin_7.5_+inf                    96.0    4.0
#
# 		 Discrétisation de la variable 'RF_GP_SUPPLEMENT_PUB_CO'
# 			 Seuils utilisés : [-inf, np.float64(-0.4797297269105911), np.float64(-0.26013512909412384), np.float64(19.472222328186035), inf]
# 			 Entropie pondérée : 0.1357
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT               False  True
# 			   CLASS_RF_GP_SUPPLEMENT_PUB_CO
# 			   bin_-inf_-0.48                  96.0    4.0
# 			   bin_-0.48_-0.26                 99.0    1.0
# 			   bin_-0.26_19.47                 98.0    2.0
# 			   bin_19.47_+inf                  93.0    7.0
#
# 		 Discrétisation de la variable 'NB_GP_AD4'
# 			 Seuils utilisés : [-inf, np.float64(1.5), np.float64(2.5), np.float64(19.5), inf]
# 			 Entropie pondérée : 0.1402
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT  False  True
# 			   CLASS_NB_GP_AD4
# 			   bin_-inf_1.5       98.0    2.0
# 			   bin_1.5_2.5        97.0    3.0
# 			   bin_2.5_19.5       97.0    3.0
# 			   bin_19.5_+inf      97.0    3.0
#
# 		 Discrétisation de la variable 'RF_GP_AD4'
# 			 Seuils utilisés : [-inf, np.float64(-0.7361111044883728), np.float64(-0.563492089509964), np.float64(-0.43050193786621094), inf]
# 			 Entropie pondérée : 0.1335
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT  False  True
# 			   CLASS_RF_GP_AD4
# 			   bin_-inf_-0.74     95.0    5.0
# 			   bin_-0.74_-0.56    97.0    3.0
# 			   bin_-0.56_-0.43    99.0    1.0
# 			   bin_-0.43_+inf     97.0    3.0
#
# 		 Discrétisation de la variable 'NB_GP_EMAILING'
# 			 Seuils utilisés : [-inf, np.float64(0.5), inf]
# 			 Entropie pondérée : 0.1401
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT      False  True
# 			   CLASS_NB_GP_EMAILING
# 			   bin_-inf_0.5           98.0    2.0
# 			   bin_0.5_+inf          100.0    0.0
#
# 		 Discrétisation de la variable 'RF_GP_EMAILING'
# 			 Seuils utilisés : [-inf, np.float64(-0.7361111044883728), np.float64(-0.7182539701461792), np.float64(-0.4519519507884979), inf]
# 			 Entropie pondérée : 0.1329
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT      False  True
# 			   CLASS_RF_GP_EMAILING
# 			   bin_-inf_-0.74         94.0    6.0
# 			   bin_-0.74_-0.72        97.0    3.0
# 			   bin_-0.72_-0.45        99.0    1.0
# 			   bin_-0.45_+inf        100.0    0.0
#
# 		 Discrétisation de la variable 'NB_GP_CM'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(1.5), np.float64(2.5), inf]
# 			 Entropie pondérée : 0.1387
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT  False  True
# 			   CLASS_NB_GP_CM
# 			   bin_-inf_0.5       98.0    2.0
# 			   bin_0.5_1.5       100.0    0.0
# 			   bin_1.5_2.5       100.0    0.0
# 			   bin_2.5_+inf      100.0    0.0
#
# 		 Discrétisation de la variable 'RF_GP_CM'
# 			 Seuils utilisés : [-inf, np.float64(-0.7361111044883728), np.float64(-0.7182539701461792), np.float64(-0.44594594836235046), inf]
# 			 Entropie pondérée : 0.1323
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT  False  True
# 			   CLASS_RF_GP_CM
# 			   bin_-inf_-0.74     95.0    5.0
# 			   bin_-0.74_-0.72    97.0    3.0
# 			   bin_-0.72_-0.45    99.0    1.0
# 			   bin_-0.45_+inf    100.0    0.0
#
# 		 Discrétisation de la variable 'RECENCE_FACTURATION'
# 			 Seuils utilisés : [-inf, inf]
# 			 Entropie pondérée : 0.1017
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT           False  True
# 			   CLASS_RECENCE_FACTURATION
# 			   bin_-inf_+inf              100.0    0.0
# 			   Group date future           93.0    7.0
# 			   Group date manquante       100.0    0.0
#
# 		 Discrétisation de la variable 'RECENCE_ENREGISTREMENT_COMPTE'
# 			 Seuils utilisés : [-inf, np.float64(1062.5), np.float64(4470.5), np.float64(7092.5), inf]
# 			 Entropie pondérée : 0.1357
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT                     False  True
# 			   CLASS_RECENCE_ENREGISTREMENT_COMPTE
# 			   bin_-inf_1062.5                       99.0    1.0
# 			   bin_1062.5_4470.5                     98.0    2.0
# 			   bin_4470.5_7092.5                     97.0    3.0
# 			   bin_7092.5_+inf                       96.0    4.0
# 			   Group date manquante                  97.0    3.0
#
# 		 Discrétisation de la variable 'RECENCE_BLOCAGE'
# 			 Seuils utilisés : [-inf, np.float64(884.5), np.float64(2435.5), np.float64(3678.5), inf]
# 			 Entropie pondérée : 0.1379
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT       False  True
# 			   CLASS_RECENCE_BLOCAGE
# 			   bin_-inf_884.5          99.0    1.0
# 			   bin_884.5_2435.5        98.0    2.0
# 			   bin_2435.5_3678.5       96.0    4.0
# 			   bin_3678.5_+inf         98.0    2.0
# 			   Group date future       98.0    2.0
# 			   Group date manquante    97.0    3.0
#
# 		 Discrétisation de la variable 'RECENCE_ARRET'
# 			 Seuils utilisés : [-inf, inf]
# 			 Entropie pondérée : 0.1379
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT      False  True
# 			   CLASS_RECENCE_ARRET
# 			   bin_-inf_+inf         100.0    0.0
# 			   Group date future     100.0    0.0
# 			   Group date manquante   98.0    2.0
#
# 		 Discrétisation de la variable 'RECENCE_CREATION_ENTREPRISE'
# 			 Seuils utilisés : [-inf, np.float64(894.5), np.float64(1891.5), np.float64(4905.5), inf]
# 			 Entropie pondérée : 0.1387
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT                   False  True
# 			   CLASS_RECENCE_CREATION_ENTREPRISE
# 			   bin_-inf_894.5                      99.0    1.0
# 			   bin_894.5_1891.5                    99.0    1.0
# 			   bin_1891.5_4905.5                   98.0    2.0
# 			   bin_4905.5_+inf                     97.0    3.0
# 			   Group date future                   98.0    2.0
# 			   Group date manquante                97.0    3.0
#
# 		 Discrétisation de la variable 'RECENCE_COMMANDE'
# 			 Seuils utilisés : [-inf, inf]
# 			 Entropie pondérée : 0.1017
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT        False  True
# 			   CLASS_RECENCE_COMMANDE
# 			   bin_-inf_+inf            98.0    2.0
# 			   Group date future        92.0    8.0
# 			   Group date manquante    100.0    0.0
#
# 		 Discrétisation de la variable 'RECENCE_PARUTION'
# 			 Seuils utilisés : [-inf, np.float64(48.0), inf]
# 			 Entropie pondérée : 0.1010
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT        False  True
# 			   CLASS_RECENCE_PARUTION
# 			   bin_-inf_48             100.0    0.0
# 			   bin_48_+inf              99.0    1.0
# 			   Group date future        92.0    8.0
# 			   Group date manquante    100.0    0.0
#
# 		 Discrétisation de la variable 'RECENCE_MAJ_CREDITSAFE'
# 			 Seuils utilisés : [-inf, np.float64(493.5), np.float64(763.5), np.float64(1076.5), inf]
# 			 Entropie pondérée : 0.1376
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT              False  True
# 			   CLASS_RECENCE_MAJ_CREDITSAFE
# 			   bin_-inf_493.5                 99.0    1.0
# 			   bin_493.5_763.5                99.0    1.0
# 			   bin_763.5_1076.5               99.0    1.0
# 			   bin_1076.5_+inf                98.0    2.0
# 			   Group date future              98.0    2.0
# 			   Group date manquante           97.0    3.0
#
# 		 Discrétisation de la variable 'RECENCE_OPPORTUNITE'
# 			 Seuils utilisés : [-inf, np.float64(50.5), np.float64(366.5), np.float64(752.5), inf]
# 			 Entropie pondérée : 0.1194
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT           False  True
# 			   CLASS_RECENCE_OPPORTUNITE
# 			   bin_-inf_50.5               99.0    1.0
# 			   bin_50.5_366.5              99.0    1.0
# 			   bin_366.5_752.5            100.0    0.0
# 			   bin_752.5_+inf              98.0    2.0
# 			   Group date future           94.0    6.0
# 			   Group date manquante       100.0    0.0
#
# 		 Discrétisation de la variable 'RECENCE_DERNIERE_GP_PUB_CO'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(252.5), np.float64(380.5), inf]
# 			 Entropie pondérée : 0.1284
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT                  False  True
# 			   CLASS_RECENCE_DERNIERE_GP_PUB_CO
# 			   bin_-inf_0.5                      100.0    0.0
# 			   bin_0.5_252.5                      96.0    4.0
# 			   bin_252.5_380.5                    95.0    5.0
# 			   bin_380.5_+inf                     99.0    1.0
#
# 		 Discrétisation de la variable 'RECENCE_DERNIERE_RELATION_CLIENT'
# 			 Seuils utilisés : [-inf, np.float64(20.5), np.float64(49.5), np.float64(348.5), inf]
# 			 Entropie pondérée : 0.1357
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT                        False  True
# 			   CLASS_RECENCE_DERNIERE_RELATION_CLIENT
# 			   bin_-inf_20.5                            97.0    3.0
# 			   bin_20.5_49.5                            97.0    3.0
# 			   bin_49.5_348.5                           98.0    2.0
# 			   bin_348.5_+inf                          100.0    0.0
# 			   Group date future                        96.0    4.0
#
# 		 Discrétisation de la variable 'RECENCE_DERNIERE_GP_PROG_BU'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(367.5), inf]
# 			 Entropie pondérée : 0.1395
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT                   False  True
# 			   CLASS_RECENCE_DERNIERE_GP_PROG_BU
# 			   bin_-inf_0.5                        98.0    2.0
# 			   bin_0.5_367.5                       96.0    4.0
# 			   bin_367.5_+inf                      97.0    3.0
#
# 		 Discrétisation de la variable 'RECENCE_DERNIERE_GP_CM'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(360.5), inf]
# 			 Entropie pondérée : 0.1387
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT              False  True
# 			   CLASS_RECENCE_DERNIERE_GP_CM
# 			   bin_-inf_0.5                   98.0    2.0
# 			   bin_0.5_360.5                 100.0    0.0
# 			   bin_360.5_+inf                100.0    0.0
#
# 		 Discrétisation de la variable 'RECENCE_DERNIERE_GP_DISPLAY'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(178.5), np.float64(385.5), inf]
# 			 Entropie pondérée : 0.1367
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT                   False  True
# 			   CLASS_RECENCE_DERNIERE_GP_DISPLAY
# 			   bin_-inf_0.5                        99.0    1.0
# 			   bin_0.5_178.5                       97.0    3.0
# 			   bin_178.5_385.5                     95.0    5.0
# 			   bin_385.5_+inf                      98.0    2.0
#
# 		 Discrétisation de la variable 'RECENCE_DERNIERE_GP_AD4'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(128.5), inf]
# 			 Entropie pondérée : 0.1402
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT               False  True
# 			   CLASS_RECENCE_DERNIERE_GP_AD4
# 			   bin_-inf_0.5                    98.0    2.0
# 			   bin_0.5_128.5                   97.0    3.0
# 			   bin_128.5_+inf                  97.0    3.0
#
# 		 Discrétisation de la variable 'RECENCE_DERNIERE_GP_DIVERTO'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(185.5), np.float64(375.5), inf]
# 			 Entropie pondérée : 0.1384
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT                   False  True
# 			   CLASS_RECENCE_DERNIERE_GP_DIVERTO
# 			   bin_-inf_0.5                        98.0    2.0
# 			   bin_0.5_185.5                       95.0    5.0
# 			   bin_185.5_375.5                     94.0    6.0
# 			   bin_375.5_+inf                      98.0    2.0
#
# 		 Discrétisation de la variable 'RECENCE_DERNIERE_GP_SOCIAL'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(142.5), np.float64(345.5), inf]
# 			 Entropie pondérée : 0.1392
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT                  False  True
# 			   CLASS_RECENCE_DERNIERE_GP_SOCIAL
# 			   bin_-inf_0.5                       98.0    2.0
# 			   bin_0.5_142.5                      96.0    4.0
# 			   bin_142.5_345.5                    94.0    6.0
# 			   bin_345.5_+inf                     97.0    3.0
#
# 		 Discrétisation de la variable 'RECENCE_DERNIERE_GP_AUTRE'
# 			 Seuils utilisés : [-inf, np.float64(1.5), np.float64(198.5), np.float64(385.5), inf]
# 			 Entropie pondérée : 0.1364
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT                 False  True
# 			   CLASS_RECENCE_DERNIERE_GP_AUTRE
# 			   bin_-inf_1.5                      99.0    1.0
# 			   bin_1.5_198.5                     97.0    3.0
# 			   bin_198.5_385.5                   94.0    6.0
# 			   bin_385.5_+inf                    98.0    2.0
#
# 		 Discrétisation de la variable 'RECENCE_DERNIERE_GP_SUPPLEMENT_PUB_CO'
# 			 Seuils utilisés : [-inf, np.float64(0.5), np.float64(246.5), np.float64(405.5), inf]
# 			 Entropie pondérée : 0.1395
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT                             False  True
# 			   CLASS_RECENCE_DERNIERE_GP_SUPPLEMENT_PUB_CO
# 			   bin_-inf_0.5                                  98.0    2.0
# 			   bin_0.5_246.5                                 97.0    3.0
# 			   bin_246.5_405.5                               97.0    3.0
# 			   bin_405.5_+inf                                99.0    1.0
#
# 		 Discrétisation de la variable 'RECENCE_DERNIERE_GP_REF_PAYANT'
# 			 Seuils utilisés : [-inf, np.float64(41.5), np.float64(327.5), inf]
# 			 Entropie pondérée : 0.1399
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT                      False  True
# 			   CLASS_RECENCE_DERNIERE_GP_REF_PAYANT
# 			   bin_-inf_41.5                          98.0    2.0
# 			   bin_41.5_327.5                         95.0    5.0
# 			   bin_327.5_+inf                         96.0    4.0
#
# 		 Discrétisation de la variable 'RECENCE_DERNIERE_GP_EMAILING'
# 			 Seuils utilisés : [-inf, np.float64(15.5), inf]
# 			 Entropie pondérée : 0.1401
# 			 Répartition des classes :
# 			   FL_ACHAT_PRODUIT                    False  True
# 			   CLASS_RECENCE_DERNIERE_GP_EMAILING
# 			   bin_-inf_15.5                        98.0    2.0
# 			   bin_15.5_+inf                       100.0    0.0
#
# 	 Discrétisation terminée.
# ---
# ---
# 	 Lancement du regroupement des modalités catégorielles.
# 		 Regroupement des modalités de 'DEPARTEMENT'
# 			 IV initial : 0.2456 (pour 110 modalités)
# 			   > k=2 → IV = 0.2633
# 			   > k=3 → IV = 0.2728
# 			   > k=4 → IV = 0.2575
# 			   > k=5 → IV = 0.2798
# 			 Choix optimal : 5 groupes (IV=0.2798 >= IV origine=0.2456)
#
# 		 Regroupement des modalités de 'CODE_POSTAL'
# 			 IV initial : 2.1691 (pour 1457 modalités)
# 			   > k=2 → IV = 0.0406
# 			   > k=3 → IV = 3.1759
# 			   > k=4 → IV = 3.1690
# 			   > k=5 → IV = 3.2181
# 			 Choix optimal : 5 groupes (IV=3.2181 >= IV origine=2.1691)
#
# 		 Regroupement des modalités de 'STATUT_SOCIETE'
# 			 IV initial : 0.0586 (pour 11 modalités)
# 			   > k=2 → IV = 0.0346
# 			   > k=3 → IV = 0.0350
# 			   > k=4 → IV = 0.0349
# 			   > k=5 → IV = 0.0321
# 			 Pas de meilleur IV -> tentative fallback avec seuil WoE de 0.20
# 			   > IV fallback = 0.0597
# 			   > Fallback accepté : 8 groupes (IV=0.0597 >= IV origine=0.0586)
#
# 		 Regroupement des modalités de 'TYPE_FACTURE'
# 			 IV initial : 0.0445 (pour 3 modalités)
# 			   > k=2 → IV = 0.0023
# 			   > k=3 → IV = 0.0445
# 			 Choix optimal : 3 groupes (IV=0.0445 >= IV origine=0.0445)
#
# 		 Regroupement des modalités de 'MODE_PAIEMENT'
# 			 IV initial : 0.0478 (pour 10 modalités)
# 			   > k=2 → IV = 0.0205
# 			   > k=3 → IV = 0.0198
# 			   > k=4 → IV = 0.0390
# 			   > k=5 → IV = 0.0375
# 			 Pas de meilleur IV -> tentative fallback avec seuil WoE de 0.20
# 			   > IV fallback = 0.0374
# 			   > Fallback non concluant, on conserve la variable originale.
#
# 		 Regroupement des modalités de 'DELAI_PAIEMENT'
# 			 IV initial : 0.1652 (pour 11 modalités)
# 			   > k=2 → IV = 0.0170
# 			   > k=3 → IV = 0.1626
# 			   > k=4 → IV = 0.1614
# 			   > k=5 → IV = 0.1621
# 			 Pas de meilleur IV -> tentative fallback avec seuil WoE de 0.20
# 			   > IV fallback = 0.1645
# 			   > Fallback non concluant, on conserve la variable originale.
#
# 		 Regroupement des modalités de 'SOURCE_CREATION'
# 			 IV initial : 0.3195 (pour 3 modalités)
# 			   > k=2 → IV = 0.3099
# 			   > k=3 → IV = 0.3195
# 			 Choix optimal : 3 groupes (IV=0.3195 >= IV origine=0.3195)
#
# 		 Regroupement des modalités de 'PROCEDURE_COLLECTIVE'
# 			 IV initial : 0.0445 (pour 14 modalités)
# 			   > k=2 → IV = 0.0464
# 			   > k=3 → IV = 0.0463
# 			   > k=4 → IV = 0.0543
# 			   > k=5 → IV = 0.0526
# 			 Choix optimal : 4 groupes (IV=0.0543 >= IV origine=0.0445)
#
# 		 Regroupement des modalités de 'STATUT_ACTIVITE'
# 			 IV initial : 0.3117 (pour 2 modalités)
# 			   > k=2 → IV = 0.3117
# 			 Choix optimal : 2 groupes (IV=0.3117 >= IV origine=0.3117)
#
# 		 Regroupement des modalités de 'STATUT_BENEFICIAIRE'
# 			 IV initial : 1.1180 (pour 3 modalités)
# 			   > k=2 → IV = 0.8707
# 			   > k=3 → IV = 1.1180
# 			 Choix optimal : 3 groupes (IV=1.1180 >= IV origine=1.1180)
#
# 		 Regroupement des modalités de 'PROFIL_CLIENT'
# 			 IV initial : 0.1233 (pour 15 modalités)
# 			   > k=2 → IV = 0.0811
# 			   > k=3 → IV = 0.0767
# 			   > k=4 → IV = 0.0883
# 			   > k=5 → IV = 0.1238
# 			 Choix optimal : 5 groupes (IV=0.1238 >= IV origine=0.1233)
#
# 		 Regroupement des modalités de 'SEGMENT'
# 			 IV initial : 0.4797 (pour 32 modalités)
# 			   > k=2 → IV = 0.2038
# 			   > k=3 → IV = 0.1902
# 			   > k=4 → IV = 0.2305
# 			   > k=5 → IV = 0.2285
# 			 Pas de meilleur IV -> tentative fallback avec seuil WoE de 0.20
# 			   > IV fallback = 0.2786
# 			   > Fallback non concluant, on conserve la variable originale.
#
# 		 Regroupement des modalités de 'SOUS_SEGMENT'
# 			 IV initial : 1.3406 (pour 241 modalités)
# 			   > k=2 → IV = 0.0020
# 			   > k=3 → IV = 1.1484
# 			   > k=4 → IV = 1.1486
# 			   > k=5 → IV = 1.1486
# 			 Pas de meilleur IV -> tentative fallback avec seuil WoE de 0.20
# 			   > IV fallback = 1.3243
# 			   > Fallback non concluant, on conserve la variable originale.
#
# 		 Regroupement des modalités de 'SEGMENT_BUMP'
# 			 IV initial : 0.3901 (pour 21 modalités)
# 			   > k=2 → IV = 0.1207
# 			   > k=3 → IV = 0.1401
# 			   > k=4 → IV = 0.2698
# 			   > k=5 → IV = 0.2781
# 			 Pas de meilleur IV -> tentative fallback avec seuil WoE de 0.20
# 			   > IV fallback = 0.2784
# 			   > Fallback non concluant, on conserve la variable originale.
#
# 		 Regroupement des modalités de 'STATUT_GROUPEMENT'
# 			 IV initial : 0.0788 (pour 5 modalités)
# 			   > k=2 → IV = 0.0596
# 			   > k=3 → IV = 0.0633
# 			   > k=4 → IV = 0.0789
# 			   > k=5 → IV = 0.0788
# 			 Choix optimal : 4 groupes (IV=0.0789 >= IV origine=0.0788)
#
# 		 Regroupement des modalités de 'GROUPEMENT'
# 			 IV initial : 1.6843 (pour 1980 modalités)
# 			   > k=2 → IV = 1.1560
# 			   > k=3 → IV = 1.2038
# 			   > k=4 → IV = 2.5032
# 			   > k=5 → IV = 2.5058
# 			 Choix optimal : 5 groupes (IV=2.5058 >= IV origine=1.6843)
#
# 		 Regroupement des modalités de 'RECORD_TYPE_NAME'
# 			 IV initial : 0.3177 (pour 5 modalités)
# 			   > k=2 → IV = 0.0357
# 			   > k=3 → IV = 0.2680
# 			   > k=4 → IV = 0.2971
# 			   > k=5 → IV = 0.3177
# 			 Choix optimal : 5 groupes (IV=0.3177 >= IV origine=0.3177)
#
# 		 Regroupement des modalités de 'ETAPE_OPPORTUNITE'
# 			 IV initial : 0.3932 (pour 6 modalités)
# 			   > k=2 → IV = 0.3431
# 			   > k=3 → IV = 0.3863
# 			   > k=4 → IV = 0.3866
# 			   > k=5 → IV = 0.3931
# 			 Pas de meilleur IV -> tentative fallback avec seuil WoE de 0.20
# 			   > IV fallback = 0.3932
# 			   > Fallback non concluant, on conserve la variable originale.
#
# 		 Regroupement des modalités de 'TYPE_PRODUIT_OPPORTUNITE'
# 			 IV initial : 0.4297 (pour 5 modalités)
# 			   > k=2 → IV = 0.3431
# 			   > k=3 → IV = 0.3959
# 			   > k=4 → IV = 0.4242
# 			   > k=5 → IV = 0.4297
# 			 Choix optimal : 5 groupes (IV=0.4297 >= IV origine=0.4297)
#
# 		 Regroupement des modalités de 'STATUT_DETAIL_PERE'
# 			 IV initial : 0.4157 (pour 4 modalités)
# 			   > k=2 → IV = 0.0004
# 			   > k=3 → IV = 0.4157
# 			   > k=4 → IV = 0.4157
# 			 Choix optimal : 3 groupes (IV=0.4157 >= IV origine=0.4157)
#
# 		 Regroupement des modalités de 'DETAIL_TYPE_SUPPORT'
# 			 IV initial : 0.1844 (pour 4 modalités)
# 			   > k=2 → IV = 0.1329
# 			   > k=3 → IV = 0.1842
# 			   > k=4 → IV = 0.1844
# 			 Choix optimal : 4 groupes (IV=0.1844 >= IV origine=0.1844)
#
# 		 Regroupement des modalités de 'DETAIL_TYPE_PRODUIT'
# 			 IV initial : 0.1757 (pour 4 modalités)
# 			   > k=2 → IV = 0.1553
# 			   > k=3 → IV = 0.1691
# 			   > k=4 → IV = 0.1757
# 			 Choix optimal : 4 groupes (IV=0.1757 >= IV origine=0.1757)
#
# 		 Regroupement des modalités de 'FORME_JURIDIQUE_MISSING'
# 			 IV initial : 0.4657 (pour 175 modalités)
# 			   > k=2 → IV = 0.2255
# 			   > k=3 → IV = 0.2927
# 			   > k=4 → IV = 0.3261
# 			   > k=5 → IV = 0.5202
# 			 Choix optimal : 5 groupes (IV=0.5202 >= IV origine=0.4657)
#
# 		 Regroupement des modalités de 'INDICATEUR_RFM'
# 			 IV initial : 0.4307 (pour 6 modalités)
# 			   > k=2 → IV = 0.3905
# 			   > k=3 → IV = 0.4278
# 			   > k=4 → IV = 0.4301
# 			   > k=5 → IV = 0.4307
# 			 Pas de meilleur IV -> tentative fallback avec seuil WoE de 0.20
# 			   > IV fallback = 0.4307
# 			   > Fallback non concluant, on conserve la variable originale.
#
# 		 Regroupement des modalités de 'CD_DEPARTEMENT'
# 			 IV initial : 0.2458 (pour 109 modalités)
# 			   > k=2 → IV = 0.2633
# 			   > k=3 → IV = 0.2728
# 			   > k=4 → IV = 0.2575
# 			   > k=5 → IV = 0.2798
# 			 Choix optimal : 5 groupes (IV=0.2798 >= IV origine=0.2458)
#
# 		 Regroupement des modalités de 'REGION'
# 			 IV initial : 0.1149 (pour 16 modalités)
# 			   > k=2 → IV = 0.1103
# 			   > k=3 → IV = 0.1091
# 			   > k=4 → IV = 0.1027
# 			   > k=5 → IV = 0.1015
# 			 Pas de meilleur IV -> tentative fallback avec seuil WoE de 0.20
# 			   > IV fallback = 0.1107
# 			   > Fallback non concluant, on conserve la variable originale.
#
# 	 Regroupement des modalités terminé.
# ---
# ---
# 	 Lancement de la sélection des features.
# 		 Split 1/5 - Variables sélectionnées : ['FL_RF_GP_PUB_CO', 'FL_RELATION_CLIENT_3M', 'FL_RELATION_CLIENT_9M', 'FL_RF_GP_DISPLAY', 'FL_OPPORTUNITE', 'FL_RF_GP_DIVERTO', 'FL_RF_GP_PROG_BU', 'FL_RF_GP_AUTRE', 'FL_RELATION_CLIENT_6M', 'MOIS_SAISON', 'FL_RF_GP_EMAILING', 'FL_RF_GP_SUPPLEMENT_PUB_CO']
# 		 Split 2/5 - Variables sélectionnées : ['FL_RF_GP_PUB_CO', 'FL_RELATION_CLIENT_3M', 'FL_OPPORTUNITE', 'FL_RF_GP_DISPLAY', 'FL_RELATION_CLIENT_9M', 'FL_RF_GP_DIVERTO', 'FL_RELATION_CLIENT_6M', 'FL_RF_GP_PROG_BU', 'MOIS_SAISON', 'FL_RF_GP_REF_PAYANT', 'FL_RF_GP_AUTRE', 'FL_RF_GP_SUPPLEMENT_PUB_CO', 'FL_RF_GP_EMAILING']
# 		 Split 3/5 - Variables sélectionnées : ['FL_RF_GP_PUB_CO', 'FL_RELATION_CLIENT_3M', 'FL_RF_GP_DISPLAY', 'FL_OPPORTUNITE', 'FL_RELATION_CLIENT_9M', 'FL_RF_GP_DIVERTO', 'FL_RF_GP_AUTRE', 'FL_RELATION_CLIENT_6M', 'FL_RF_GP_SOCIAL', 'MOIS_SAISON', 'FL_RF_GP_REF_PAYANT', 'FL_RF_GP_EMAILING']
# 		 Split 4/5 - Variables sélectionnées : ['FL_RF_GP_PUB_CO', 'FL_RELATION_CLIENT_3M', 'FL_RELATION_CLIENT_9M', 'FL_RF_GP_DISPLAY', 'FL_OPPORTUNITE', 'FL_RF_GP_DIVERTO', 'FL_RF_GP_AUTRE', 'FL_RF_GP_SOCIAL', 'FL_RELATION_CLIENT_6M', 'MOIS_SAISON', 'FL_RF_GP_EMAILING', 'FL_RF_GP_REF_PAYANT', 'FL_RF_GP_SUPPLEMENT_PUB_CO']
# 		 Split 5/5 - Variables sélectionnées : ['FL_RF_GP_PUB_CO', 'FL_RELATION_CLIENT_3M', 'FL_RELATION_CLIENT_9M', 'FL_RF_GP_AUTRE', 'FL_OPPORTUNITE', 'FL_RF_GP_DIVERTO', 'FL_RF_GP_PROG_BU', 'FL_RELATION_CLIENT_6M', 'MOIS_SAISON', 'FL_RF_GP_REF_PAYANT', 'FL_RF_GP_SUPPLEMENT_PUB_CO', 'FL_RF_GP_EMAILING']
# 		 Splits * - Variables consolidées (>=3 splits) : ['FL_RF_GP_PUB_CO', 'FL_RELATION_CLIENT_3M', 'FL_RELATION_CLIENT_9M', 'FL_RF_GP_DISPLAY', 'FL_OPPORTUNITE', 'FL_RF_GP_DIVERTO', 'FL_RF_GP_PROG_BU', 'FL_RF_GP_AUTRE', 'FL_RELATION_CLIENT_6M', 'MOIS_SAISON', 'FL_RF_GP_EMAILING', 'FL_RF_GP_SUPPLEMENT_PUB_CO', 'FL_RF_GP_REF_PAYANT']
#
# 	   > Nombre de variables sélectionnées : 16 | Variables : ['FL_RF_GP_PUB_CO', 'FL_RELATION_CLIENT_3M', 'FL_RELATION_CLIENT_9M', 'FL_RF_GP_DISPLAY', 'FL_OPPORTUNITE', 'FL_RF_GP_DIVERTO', 'FL_RF_GP_PROG_BU', 'FL_RF_GP_AUTRE', 'FL_RELATION_CLIENT_6M', 'MOIS_SAISON', 'FL_RF_GP_EMAILING', 'FL_RF_GP_SUPPLEMENT_PUB_CO', 'FL_RF_GP_REF_PAYANT', 'FL_ACHAT_PRODUIT', 'CLASSE_PMG_N', 'PART_DIGITALISATION']
# 	 Sélection des features terminé.
# ---
# ---
# 	 Lancement du pré-traitement des features.
# 		 > 'MOIS_SAISON' - Mapping appliqué : {'8': 0, '7': 1, '5': 2, '6': 3, '3': 4, '9': 5, '4': 6, '11': 7, '2': 8, '1': 9, '10': 10, '12': 11, '<inconnu>': -1}
#
# 		 > 'CLASSE_PMG_N' - Mapping appliqué : {'Très petit': 0, 'Petit': 1, 'Moyen': 2, 'Gros': 3, 'Très gros': 4, '<inconnu>': -1}
#
# 		 > 'PART_DIGITALISATION' - Mapping appliqué : {'bin_-inf_0': 0, 'bin_0_0.36': 1, 'bin_0.36_0.97': 2, 'bin_0.97_+inf': 3, '<inconnu>': -1}
#
#
# 	   > Détection de biais
# 			 Listes des colonnes retirées : set()
# 	 Pré-traitement des features terminé.
# ---
# ---
# 	 Lancement du ré-échantillonnage en over-sampling.
#
# 	  > Tx d'acheteurs avant ré-échantillonnage :  1.98 %
# 	  > Effectifs avant ré-échantillonnage :
# 		 FL_ACHAT_PRODUIT
# 		 False    123395
# 		 True       2495
#
# 	  > Tx d'acheteurs après ré-échantillonnage :  7.11 %
# 	  > Effectifs après ré-échantillonnage :
# 		 FL_ACHAT_PRODUIT
# 		 False    123395
# 		 True       9441
# 	 Ré-échantillonnage en over-sampling terminé.
# ---
# 	 Préparation des données pour la modélisation terminée
# 		 > Dataset train
# 			 Nombre de lignes :  132836
# 			 Nombre de features :  16
# 			 Tx d'acheteurs :  7.11 % | Tx de non-acheteurs :  92.89 %
# ---
#
# ---
# 	 Lancement de la modélisation Random Forest
# 		 > Meilleurs paramètres trouvés :
# 			 {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 300}
#
# 		 > Grille de poids des modalités :
# 			                       Variable       Modalité      Poids
# 			 0                 CLASSE_PMG_N     Très petit   0.000000
# 			 1                 CLASSE_PMG_N          Petit  17.064750
# 			 2                 CLASSE_PMG_N          Moyen  22.830412
# 			 3                 CLASSE_PMG_N           Gros  20.633081
# 			 4                 CLASSE_PMG_N      Très gros  18.565375
# 			 5               FL_OPPORTUNITE           Faux   0.000000
# 			 6               FL_OPPORTUNITE           Vrai   9.451600
# 			 7        FL_RELATION_CLIENT_3M           Faux   0.000000
# 			 8        FL_RELATION_CLIENT_3M           Vrai   4.769355
# 			 9        FL_RELATION_CLIENT_6M           Faux   0.000000
# 			 10       FL_RELATION_CLIENT_6M           Vrai   3.525640
# 			 11       FL_RELATION_CLIENT_9M           Faux   0.000000
# 			 12       FL_RELATION_CLIENT_9M           Vrai   4.357783
# 			 13              FL_RF_GP_AUTRE           Faux   5.053502
# 			 14              FL_RF_GP_AUTRE           Vrai   0.000000
# 			 15            FL_RF_GP_DISPLAY           Faux   6.252961
# 			 16            FL_RF_GP_DISPLAY           Vrai   0.000000
# 			 17            FL_RF_GP_DIVERTO           Faux   2.196294
# 			 18            FL_RF_GP_DIVERTO           Vrai   0.000000
# 			 19           FL_RF_GP_EMAILING           Faux   0.000000
# 			 20           FL_RF_GP_EMAILING           Vrai   4.738827
# 			 21            FL_RF_GP_PROG_BU           Faux   3.110807
# 			 22            FL_RF_GP_PROG_BU           Vrai   0.000000
# 			 23             FL_RF_GP_PUB_CO           Faux  10.384800
# 			 24             FL_RF_GP_PUB_CO           Vrai   0.000000
# 			 25         FL_RF_GP_REF_PAYANT           Faux   1.260934
# 			 26         FL_RF_GP_REF_PAYANT           Vrai   0.000000
# 			 27  FL_RF_GP_SUPPLEMENT_PUB_CO           Faux   1.651353
# 			 28  FL_RF_GP_SUPPLEMENT_PUB_CO           Vrai   0.000000
# 			 29                 MOIS_SAISON              7   0.517310
# 			 30                 MOIS_SAISON              5   0.000000
# 			 31                 MOIS_SAISON              3   3.712232
# 			 32                 MOIS_SAISON              9   6.005878
# 			 33                 MOIS_SAISON             11   6.522617
# 			 34                 MOIS_SAISON              1   5.310775
# 			 35         PART_DIGITALISATION     bin_-inf_0   9.448488
# 			 36         PART_DIGITALISATION     bin_0_0.36  13.893117
# 			 37         PART_DIGITALISATION  bin_0.36_0.97  12.623010
# 			 38         PART_DIGITALISATION  bin_0.97_+inf   0.000000
#
# 		 > Évaluation du modèle: Random Forest
# 			  Lift global                 3.5152
# 			  Taux faux positifs (FPR)    0.1198
# 			  F0.5-score                  0.0837
# 	 Modélisation Random Forest terminée.
# ---
